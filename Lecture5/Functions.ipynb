# %% [markdown]
# ---
# title: Functions
# abstract: |
#     Functions allow programmers to reuse code that is efficiently implemented and well-tested. This notebook not only demonstrates the basic syntax for using and writing functions, but also uses concrete examples to illustrate the importance of code reuse. It highlights the flexibility of functions by showing how they can be applied with different arguments to solve similar problems and how they can be customized to suit specific applications.
# skip-execution: true
# ---

# %%
import math
import ROOT

# %% [markdown]
# ## What is a Function?

# %% [markdown]
# A function is a *callable* object, e.g.:

# %%
callable(callable), callable(1)

# %% [markdown]
# The function `callable` is callable because
# - it can be *called/invoked* with some input *arguments/parameters* such as `1` enclosed by parentheses `()`, and then
# - *returns* some value computed from the input arguments, such as the boolean value `False` to indicate that the input argument `1` is not callable.

# %% [markdown]
# A function can be defined using the [`def` keyword](https://docs.python.org/3/reference/compound_stmts.html#function-definitions)[^def_tutorial]:
#
# ```ebnf
# [decorators] "def" funcname [type_params] "(" [parameter_list] ")"
#                            ["->" expression] ":" suite
# ```
#
# [^def_tutorial]: The [tutorial on `def`](https://docs.python.org/3/tutorial/controlflow.html#defining-functions) may be easier to read than the formal definition.

# %% [markdown]
# E.g., a simple function that prints "Hello, World!" can be defined as follows:

# %%
# Function definition
def say_hello():
    print("Hello, World!")

# %%
# Function invocation
say_hello()

# %% [markdown]
# To make a function more powerful and solve different problems,
# - use a [return statement](https://docs.python.org/3/reference/simple_stmts.html#the-return-statement) to return a value that
# - depends on some input arguments.

# %%
def increment(x):
    return x + 1


increment(3)

# %% [markdown]
# A function must have a return value. By default `None` is returned if the function does not have a return statement:

# %%
print(f"The return value is {say_hello()}.", )

# %% [markdown]
# We can also have multiple input arguments.

# %%
def length_of_hypotenuse(a, b):
    return (a ** 2 + b ** 2) ** 0.5

length_of_hypotenuse(1, 2), length_of_hypotenuse(3, 4)

# %% [markdown]
# The arguments are evaluated from left to right:

# %%
print("1st input:", input(), "\n2nd input:", input())

# %% [markdown]
# ::::{important}
#
# In summary, a function in Python
# - may have any number (even zero) of input arguments, evaluated from left to right,
# - may have *side effects* such as printing something to the standard output, and
# - must have a return value, which can be `None`.
#
# ::::
#
# :::{exercise} agentic function writing
# :label: ex:palindrome-agentic
#
# Ask an AI agent to write a function `is_palindrome(s)` that checks if
# a string is a palindrome (reads the same forwards and backwards).
# Evaluate whether the result handles edge cases properly: empty string,
# single character, and mixed case like `"Racecar"`.
#
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# How arguments are passed into a function can be more complicated. To check if you have the correct understanding:
#
# ::::{caution} Does the code below increment `x` and prints `4`?
# :class: dropdown
#
# - Step 3: The function `increment` is invoked with an argument `x`.
# - Step 3-4: A local frame is created for variables local to `increment` during its execution.
#     - The *formal parameter* `x` in `def increment(x):` becomes a local variable and
#     - it is assigned the value `3` of the *actual parameter* given by the global variable `x`.
# - Step 5-6: The local (but not the global) variable `x` is incremented.
# - Step 6-7: The function call completes and the local frame is removed.
#
# ::::

# %%
# %%pytutor
# def increment(x):
#     x += 1
#
#
# x = 3
# increment(x)
# print(x)  # 4?

# %% [markdown]
# :::{exercise} agentic debugging
# :label: ex:debug-agentic
#
# Consider the following buggy function with a `NameError` due to
# variable scope confusion:
#
# ```python
# def calculate_average(scores):
#     total = sum(scores)
#     average = total / count
#     return average
# ```
#
# Ask an AI agent to fix this function. Then explain why the original
# code fails (a local variable used before it is defined) and why the
# fix works.
#
# ::::

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ::::{seealso} Can we increment a variable instead of returning its increment?
# :class: dropdown
#
# In C++, it is possible to pass an argument by reference, allowing the local
# variable to point to the same memory location as the variable being passed in.
# Unlike Python, a variable in C++ is not merely a name; it is a named container
# whose size is determined by its type.
#
# ::::

# %%
# %%cpptutor
# void increment(auto &x) {
#     x += 1;
# }
#
# int main() {
#     auto x = 3;
#     increment(x);
#     return 0;
# }

# %% [markdown]
# ::::{seealso}
#
# The above cell uses [`%%cpptutor` cell
# magic](https://github.com/dive4dec/jupyter-cpp-tutor) to run C++ code.
#
# ::::

# %%
# %%hermes
# Explain briefly the differences in how Python, C, and Java pass arguments to
# functions. In particular, explain
# 1. call by value,
# 2. call by reference, and
# 3. call by object reference.

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# Here's a breakdown of the three parameter-passing mechanisms:
#
# 1. Call by Value (C)
#
# - A **copy** of the argument's value is passed to the function.
# - Modifications to the parameter inside the function **do not affect** the original variable.
# - For structs, the entire struct is copied (no reference semantics for normal parameters).
# - Pointers are also passed by value — the pointer itself is copied, so reassigning it locally doesn't affect the caller's pointer, though dereferencing can mutate the pointed-to data.
#
# ```c
# void f(int x) { x = 10; }   // caller's x unchanged
# ```
#
# 2. Call by Reference (C-style "reference semantics" via pointers; C++ `&` references)
#
# C itself doesn't have true call-by-reference, but the effect is achieved with **pointers**:
#
# - The function receives a **memory address** (a copy of the pointer), so it can **mutate the original variable** through dereferencing.
# - C++ added true reference parameters (`void f(int &x)`) where aliasing is implicit — the parameter **is** the original variable.
#
# ```c
# void f(int *x) { *x = 10; }   // caller's variable is modified
# ```
#
# 3. Call by Object Reference / Call by Sharing (Python & Java)
#
# This is the model used by both Python and Java, sometimes called **call by sharing**:
#
# - What's passed is a **reference (pointer) to an object** — but the reference itself is passed **by value** (i.e., copied).
# - **Mutating** the object inside the function **is visible** to the caller because both references point to the same object.
# - **Reassigning** the parameter (`x = something`) only changes the local copy of the reference — the caller sees **no change**.
#
# ```python
# # Python
# def f(lst):
#     lst.append(1)   # caller sees this — same object mutated
#     lst = []         # caller does NOT see this — local rebind only
#
# my_list = [0]
# f(my_list)  # my_list is now [0, 1]
# ```
#
# ```java
# // Java — same behaviour
# void f(List<Integer> lst) {
#     lst.add(1);     // visible to caller
#     lst = new ArrayList<>();  // NOT visible to caller
# }
# ```
#
# **Summary table**
#
# | Mechanism | What's passed | Can mutate caller's data? | Can rebind caller's variable? |
# |---|---|---|---|
# | **Call by value** (C) | Copy of the value | No | No |
# | **Call by reference** (C++ `&`) | Alias of the variable | Yes | Yes |
# | **Call by object reference** (Python, Java) | Copy of the reference | Mutations visible | No — rebind is local only |
#
# The key takeaway: Python and Java sit **between** call-by-value and call-by-reference. You get shared object identity (so mutations propagate), but not shared variable identity (so reassignments don't).
# ::::

# %% [markdown]
# A fundamental property of functions in Python is that they are [*first-class
# citizens*](https://en.wikipedia.org/wiki/First-class_function), which means
# that a function can be
# 1. assigned to a variable,
# 2. passed as an input argument, and
# 3. returned by a function.

# %%
# %%hermes
# Are there programming languages that do not treat functions as
# first-class citizens? Why?

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# Several languages do not treat functions as first-class citizens. Notable examples:
#
# C (the classic example)
#
# - Functions **cannot** be stored in variables, returned from other functions, or passed as arguments directly.
# - The closest you get is **function pointers**, which are a second-class type — they carry no closure information (no captured environment), have limited type safety, and can't be created dynamically.
# - No nested functions, no lambdas.
#
# COBOL / Fortran (traditional versions)
#
# - Functions exist, but cannot be passed, stored, or returned. No function literals, no higher-order functions.
#
# MATLAB (partially)
#
# - Function handles exist, but with limitations compared to first-class treatment.
#
# Why?
#
# Several design reasons explain the absence:
#
# 1. **Performance / runtime model** — Storing functions dynamically requires heap allocation, garbage collection, and runtime dispatch. C was designed in the 1970s for minimal overhead and direct mapping to machine code.
#
# 2. **No closures** — First-class functions in most languages come paired with closures (capturing surrounding variables). That requires runtime environments to manage. Languages without closures struggle to justify the overhead of full first-class treatment.
#
# 3. **Simplicity & compile-time resolution** — When function calls are resolved at compile time and bound statically, the compiler can inline, optimize, and enforce calling conventions. Allowing functions to flow freely through data structures introduces dynamic dispatch and indirection that complicates compilation and optimization.
#
# 4. **Memory layout** — In C, functions live in the code segment with fixed addresses. Treating them as data requires them to behave like heap-allocated objects, which clashes with the language's execution model.
#
# 5. **Philosophical / procedural orientation** — Languages designed for structured programming (C, Pascal, COBOL) viewed functions as declarative building blocks of programs, not as values that could be manipulated.
#
# ::::

# %% [markdown]
# The following is a simple illustration that defines an identity function that
# returns the input argument.

# %%
def i(x):
    return x

i(i) == i and i.__name__ == 'i'

# %% [markdown]
# A function can also be defined using the [`lambda`
# expression](https://docs.python.org/3/reference/expressions.html#lambda), which
# creates an anonymous function:[^colon]
#
# [^colon]: Note that the colon in `lambda ...:` cannot be followed by line break
# because it expects an expression rather than a suite.

# %%
(i := lambda x: x)(i) == i and i.__name__ == "<lambda>"

# %% [markdown]
# A non-trivial example is the following implementation of the boolean values as
# functions:

# %%
# %%pytutor
# def true(x, y): return x
# def false(x, y): return y
# def ifthenelse(b, x, y): return b(x, y)
# print(ifthenelse(true, "A", "B"))
# print(ifthenelse(false, "A", "B"))

# %% [markdown]
# :::::{seealso} Why the name `<lambda>` for anonymous function?
# :class: dropdown
#
# The expression $\lambda x.M$, known as *function abstraction*, was defined by
# [Alonzo Church](https://en.wikipedia.org/wiki/Alonzo_Church), the Ph.D.
# supervisor of Alan Turing. This notation is used to define a function that can
# take (return) a string or another function passed in as $x$ (returned as $M$
# but with $x$ substituted by the value of $x$). What is surprising is that **a
# machine capable of taking and applying all such functions is [Turing
# complete](https://en.wikipedia.org/wiki/Turing_completeness)**. For more
# information, see
# [$\lambda$-calculus](https://en.wikipedia.org/wiki/Lambda_calculus) and watch
# the following video[^manim] or another video
# [here](https://youtu.be/eis11j_iGMs?si=X29joUgynqV3AtAO).
#
# ::::{card}
# :header: [Open in a new tab](https://www.youtube.com/embed/ViPNHMSUcog?si=RfgWdE2gjUJW_Wqc)
# :::{iframe} https://www.youtube.com/embed/ViPNHMSUcog?si=RfgWdE2gjUJW_Wqc
# :::
# ::::
#
# :::::
#
# [^manim]: The video is created using the [Python package
# `manim`](https://www.manim.community/), which is also accessible in Jupyter
# notebooks using the [cell magic
# `%%manim`](https://docs.manim.community/en/stable/reference/manim.utils.ipython_magic.ManimMagic.html).
# See the [3Blue1Brown](https://www.youtube.com/c/3blue1brown) for more videos
# created with `manim`.

# %%
# %%hermes
# How to create an infinite loop using purely the lambda expression in Python?

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# You can create self-recursion in a lambda using a **fixed-point combinator** — the **Z combinator** (Python's version; the Y combinator works for lazy languages).
#
# The trick
#
# A lambda has no name, so it can't call itself directly. The Z combinator passes a "wrapped" version of the function to itself, enabling self-recursion:
#
# ```python
# Z = lambda f: (lambda x: f(lambda *args: x(x)(*args)))(lambda x: f(lambda *args: x(x)(*args)))
# ```
#
# Infinite loop
#
# ```python
# Z(lambda f: lambda: f())()
# ```
#
# This creates a lambda that calls itself forever. In practice, Python will eventually raise `RecursionError` because of its call-stack limit — but conceptually it is an infinite loop expressed **purely with lambdas**.
#
# How it works (intuition)
#
# - `Z` takes a function `f` that expects to receive its own recursive version as an argument.
# - The `(lambda x: ...)(lambda x: ...)` pattern forces **self-application** — the inner lambda calls `x(x)`, which is the mechanism that generates the fixed point.
# - `f(lambda *args: x(x)(*args))` wraps the self-application so it only triggers on invocation (avoiding infinite evaluation in an eager language like Python).
#
# ::::

# %% [markdown]
# Perhaps you may also be interested in the following:

# %%
# %%hermes
# Why Alonzo Church used lambda for lambda calculus?

# %% [markdown]
# ## Code Reuse

# %% [markdown]
# Previously, we learned about iteration, where the same piece of code can run multiple times. Function abstraction takes this even further: It allows the same piece of code to be executed with different parameters and at different locations. Code reuse is a good programming practice. If done properly, it makes the code readable and efficient.  We will explore these benefits using a concrete example below.

# %% [markdown]
# ### Perfect Square

# %% [markdown]
# ::::{prf:definition} perfect square
# :label: def:perfect_square
#
# An integer $n$ is called a [perfect square](https://en.wikipedia.org/wiki/Square_number) if it is the square of an integer.
#
# ::::

# %% [markdown]
# For instance, the first 10 perfect squares are:

# %%
for i in range(10):
    print(i**2)

# %% [markdown]
# Instead of generating perfect squares, how about writing a function that checks if a number is a perfect square?

# %% [markdown]
# ::::{exercise}
# :label: ex:perfect_square
#
# Complete the following function to check if an integer `n` is a perfect square ([](#def:perfect_square)).
#
# ::::

# %%
def is_perfect_square(n):
    # YOUR CODE HERE
    raise NotImplementedError

# %%
# test cases
assert is_perfect_square(10**2)
assert not is_perfect_square(10**2 + 1)
assert is_perfect_square(10**10)
assert not is_perfect_square(10**10 + 1)
assert is_perfect_square(10**100)
assert not is_perfect_square(10**100 + 1)

# %% [markdown]
# As another demonstration of code reuse, the following solution uses a for loop to implement [](#def:perfect_square) exactly.

# %%
def is_perfect_square(n):
    # checks if n is the square of i for i in the range up to n (exclusive). 
    for i in range(n):
        if i**2 == n:
            return True

# %% [markdown]
# If you try running the test on the above solution, it will take an unacceptably long time to run.[^interrupt] (Why?)
#
# [^interrupt]: Use the keyboard interrupt (&#9632;) to stop the execution.

# %% [markdown]
# To properly test the function, we should modify it to fail if it takes too long to run. Implementing such a feature, called *timeout*, is difficult. Fortunately, we can reuse the code written by others. Run the following cell to
#
# 1. install the package `wrapt_timeout_decorator` and
# 2. import the function `timeout` from the module `wrapt_timeout_decorator`.

# %%
# %pip install wrapt_timeout_decorator >/dev/null 2>&1

# %%
from wrapt_timeout_decorator import timeout

def is_perfect_square(n):
    # checks if n is the square of i for i in the range up to n (exclusive). 
    for i in range(n):
        if i**2 == n:
            return True

# %% [markdown]
# You will learn how to import a function in a subsequent section ([](#importing-external-modules)). For now, let's see how to use the `timeout` function:

# %%
# enhanced test without timeout
duration = 5


@timeout(duration)  # raise error if the test does not complete in 5 seconds.
def test():
    if not input(f"Run the test with a timeout of {duration}s? [Y/n]").lower() == "n":
        assert is_perfect_square(10**2)
        assert not is_perfect_square(10**2 + 1)
        assert is_perfect_square(10**10)
        assert not is_perfect_square(10**10 + 1)
        assert is_perfect_square(10**100)
        assert not is_perfect_square(10**100 + 1)


test()  # run the test

# %% [markdown]
# ::::{note} Does the for loop implementation pass all the test cases?
# :class: dropdown
#
# `assert is_perfect_square(10**10)` fails because Python is not fast enough to go through `10**10` numbers in `5` seconds.
#
# ::::

# %% [markdown]
# To add timeout to the test, we simply
# 1. wrapped the test inside a function `test`, and
# 2. decorated it with `@timeout(duration)`.
#
# The function `test` will then be capable of raising a `FunctionDurationError` if it takes more than the specified time `duration` to run.

# %% [markdown]
# You will learn how to write a [decorator](https://book.pythontips.com/en/latest/decorators.html#decorators) later. It is a powerful way to reuse functions and other objects with additional customizations.

# %% [markdown]
# ### Integer Square Root

# %% [markdown]
# To improve the efficiency, consider the following sufficient and necessary condition for perfect squares:
#
# ::::{prf:proposition} integer square root
# :label: pro:integer-sqrt
#
# An integer $n$ is a perfect square iff
#
# $$
# n = (\lfloor \sqrt{n} \rfloor)^2,
# $$ (eq:perfect_square)
#
# namely, that the number is the square of its integer square root.
#
# ::::

# %% [markdown]
# A simple implementation is as follows:

# %%
def is_perfect_square(n):
    # check if n is the square of its integer square root
    return n == int(n**0.5) ** 2

assert is_perfect_square(10**10)

# %% [markdown]
# Note that it fixed the efficiency issue on the test case with `n` being `10**10`. Let's run all the test cases:

# %%
test()

# %% [markdown]
# ::::{note} Does it pass all the test cases?
# :class: dropdown
#
# `assert is_perfect_square(10**100)` fails because of the finite precision of floating point numbers.
#
# ::::

# %% [markdown]
# Perhaps we should use `math.isclose` instead of `==`, since floating-point precision loss in `n**0.5` for very large `n`.

# %%
def is_perfect_square(n):
    return math.isclose(n, int(n**0.5) ** 2)


assert is_perfect_square(10**100)

# %% [markdown]
# Note that it can correctly say `10**100` is a perfect square. Let's run all the test cases:

# %%
test()

# %% [markdown]
# ::::{note} Does it pass all the test cases?
# :class: dropdown
#
# `assert not is_perfect_square(10**10+1)` fails because the tolerance is too high.
#
# ::::

# %% [markdown]
# How to fix the issue? The culprit is that the computation for integer square root is not exact:

# %%
x = 10**100
int((x) ** 0.5)

# %% [markdown]
# There are [better ways to compute integer square
# root](https://en.wikipedia.org/wiki/Integer_square_root). Binary search is a
# relatively easy one to try first, although it is not the best choice.

# %%
# %%hermes
# Explain very briefly how integer square root can be implemented in Python using
# binary search.

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# Binary search works because `x²` is monotonically increasing for non-negative integers. We search for the largest integer `mid` such that `mid² ≤ n`.
#
# ```python
# def isqrt(n):
#     if n < 0: raise ValueError
#     lo, hi = 0, n
#     while lo <= hi:
#         mid = (lo + hi) // 2
#         if mid * mid <= n:
#             lo = mid + 1
#         else:
#             hi = mid - 1
#     return hi  # hi is the largest int where hi² ≤ n
# ```
#
# **How it works:**
# - If `mid² ≤ n`, the answer is `mid` or higher → move `lo` up.
# - If `mid² > n`, the answer is below `mid` → move `hi` down.
# - When the loop ends, `hi` holds the integer square root.
#
# ::::

# %% [markdown]
# But there is a much easier way to have a better implementation: Code reuse! Try
# `math.isqrt` for [](#ex:perfect_square) and check that you can pass all the
# test cases instantly.

# %%
x = 10**100
math.isqrt(x), int((x) ** 0.5)

# %% [markdown]
# ::::{seealso} How is `isqrt` implemented?
# :class: dropdown
#
# `math.isqrt` implements an [adaptive-precision pure-integer version of Newton's
# iteration](https://github.com/python/cpython/blob/e5ab0b6aa68009a3f50b141ec013dacee3676db9/Modules/mathmodule.c#L1599C11-L1599C72).
# The [source
# code](https://github.com/python/cpython/blob/e5ab0b6aa68009a3f50b141ec013dacee3676db9/Modules/mathmodule.c#L1791)
# is written in C, but there is a [Python
# implementation](https://github.com/python/cpython/blob/e5ab0b6aa68009a3f50b141ec013dacee3676db9/Modules/mathmodule.c#L1629)
# given in the source code, along with a [sketch of
# proof](https://github.com/python/cpython/blob/e5ab0b6aa68009a3f50b141ec013dacee3676db9/Modules/mathmodule.c#L1652).
#
# ::::

# %%
# %%hermes
# Explain briefly in two paragraph how isqrt is implemented as an
# adaptive-precision pure-integer version of Newton's iteration.

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# Newton's method finds roots by iterating $x_{k+1} = \frac{1}{2}(x_k + \frac{n}{x_k})$. For integer square root, every division is replaced with integer division (`//`), so the entire computation stays in the integer domain with zero floating-point arithmetic. Starting from an initial guess (like `n` itself), the sequence rapidly converges downward. Because integer division truncates toward zero, the iterates monotonically decrease once they fall below the true root and naturally settle at the correct integer value without overshooting.
#
# The "adaptive precision" comes from Newton's quadratic convergence: each step roughly doubles the number of correct bits. With large integers, this means the algorithm needs only \(O(\log \log n)\) iterations regardless of bit length, while the cost per iteration adapts to the current operand size—early steps are cheap (few bits), and later steps refine the result with larger multiplications and divisions. The loop terminates when \(x_{k+1} \ge x_k\), which is the exact integer square root.
#
# ::::

# %% [markdown]
# While you may want to write self-contained codes that do not rely on external libraries, code reuse advocates would recommend you to use standard libraries as much as possible. Why?

# %% [markdown]
# Indeed, the `math` library provides functions that it does not implement:
#
# > **CPython implementation detail:** The `math` module consists mostly of thin
# *wrappers* around the platform C math library functions. - [pydoc last
# paragraph](https://docs.python.org/3/library/math.html)
#
# E.g., see the [source code wrapper for
# `log`](https://github.com/python/cpython/blob/e5ab0b6aa68009a3f50b141ec013dacee3676db9/Modules/mathmodule.c#L757).[^CORDIC]:
#
# [^CORDIC]: An efficient implementation often uses the [CORDIC
# algorithm](https://en.wikipedia.org/wiki/CORDIC).

# %%
# %%hermes
# When working on a programming assignment, should I write all the code myself,
# or is it acceptable to use standard libraries?

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# In almost all programming assignments, **you are expected and encouraged to use standard libraries**. They are part of the language itself, and knowing when to use them is a core programming skill. Reinventing built-in functionality is rarely the goal unless the assignment explicitly states otherwise.
#
# You should write things from scratch **only when**:
# - The assignment explicitly asks you to implement a specific algorithm or data structure (e.g., "implement binary search yourself" or "build a linked list without using `list`").
# - Using a library would bypass the actual learning objective of the exercise.
#
# **Rule of thumb:** If the task is about applying logic, organizing code, or solving a problem, use the standard library. If the task is about understanding how something works under the hood, implement it manually. When in doubt, check the rubric or ask your instructor.
#
# ::::

# %% [markdown]
# ## Modules

# %% [markdown]
# To facilitate code reuse, all Python codes are organized into libraries called *modules*. E.g., you can list all available modules using `pip list`:

# %%
# %pip list

# %% [markdown]
# Python searches for packages using the search path:

# %%
import sys
sys.path

# %% [markdown]
# For instance, to show the location of a package, say `jupyter-ai-hermes`, run:

# %%
# %pip show jupyter-ai-hermes

# %% [markdown]
# You can install additional packages using the commands [`pip install`](https://packaging.python.org/en/latest/tutorials/installing-packages/) for packages on [PyPI](https://pypi.org/search/).

# %% [markdown]
# The following is an example using `pip` to install a package `cowsay`:

# %%
if not input('Execute? [Y/n]').lower()=='n': 
    # %pip install cowsay

# %%
import cowsay

cowsay.cow("I am a pip installed package ((((((...ip)ip)ip)ip)ip)ip)!")

# %% [markdown]
# ::::{seealso} What does pip stand for?
# :class: dropdown
#
# "pip" is a recursive acronym that stands for **"Pip Installs Packages"** (or sometimes "Package Installer for Python").
# ::::

# %% [markdown]
# ::::{seealso} Conda environment
# :class: dropdown
#
# - You can also install additional packages using the commands [`conda
# install`](https://docs.conda.io/projects/conda/en/stable/commands/install.html)
# for packages on [Anaconda](https://anaconda.org/). Conda packages need not be
# Python packages. E.g., you can use conda to install the new super-fast [package
# manager `uv`](https://github.com/astral-sh/uv) written in Rust:
#
#   ```bash
#   conda install uv --yes
#   ```
#
# - Due to how your server is spawned using docker containers, the above
# installations do not persist when restarting the Jupyter server because the
# packages are saved to an ephemeral instead of a persistent storage. To have
# persistent installations, you can create a conda environment[^conda].
#
# [^conda]: See the
# [documentation](https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html)
# for more details on managing conda environment.
#
# ::::

# %%
# %%hermes
# Explain how to publish a python package to PyPI.

# %% [markdown]
# ::::{seealso}
# :class: dropdown
# Publishing a Python package to PyPI involves these steps:
#
# 1. **Structure your project** — Create a directory with your code, a `README.md`, `LICENSE`, and a `pyproject.toml` (the modern standard replacing `setup.py`). The `pyproject.toml` declares metadata (name, version, author) and build requirements.
#
# 2. **Build the distribution** — Run `pip install build` and then `python -m build`. This produces two artifacts in `dist/`: a **source archive** (`.tar.gz`) and a **wheel** (`.whl`).
#
# 3. **Install twine** — `pip install twine`, the official tool for uploading.
#
# 4. **Upload** — Run `twine upload dist/*`. It prompts for your PyPI username and password (or use an API token via `-p pypi-...`). For test uploads first, use `twine upload --repository testpypi dist/` to push to [TestPyPI](https://test.pypi.org/), a sandbox mirror.
#
# 5. **Install from PyPI** — Once published, anyone can run `pip install your-package-name`.
#
# ::::

# %% [markdown]
# ### Builtins Module

# %% [markdown]
# In Python, every function must come from a module, including the built-in functions:

# %%
__builtins__.print(f"`{print.__name__}` is from the {print.__module__} module.")

# %% [markdown]
# The `buildins` are automatically imported as `__builtins__` (and also `__builtin__`) along with all the functions and objects it provides because they are commonly used by programmers.

# %% [markdown]
# We can use the built-in function `dir` (*directory*) to list all built-in objects available.

# %%
print(dir(__builtins__))

# %% [markdown]
# For instance, there is a built-in function `help` for showing the *docstring* (documentation string) of functions or other objects.

# %%
help(help)  # can also show the docstring of help itself

# %%
help(__builtins__)  # can also show the docstring of a module

# %% [markdown]
# ::::{exercise}
# :label: ex:dir
#
# We can call `dir` without arguments. What does it print?
#
# :::{hint}
# :class: dropdown
#
# Try `help(dir)` or `dir?` in jupyter notebook.
# :::
#
# ::::

# %%
print(dir())

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# (importing-external-modules)=
# ### Importing External Modules

# %% [markdown]
# For other available modules, we can use the [`import` statement](https://docs.python.org/3/reference/simple_stmts.html#import) to import multiple functions or objects into the program *global frame*.

# %%
from math import ceil, log10

x = 1234
print("Number of digits of x:", ceil(log10(x)))

# %% [markdown]
# The above imports both the functions `log10` and `ceil` from `math` to compute the number $\lceil \log_{10}(x)\rceil$ of digits of a *strictly positive* integer $x$.

# %% [markdown]
# One can also import all functions from a library:

# %%
from math import *  # import all except names starting with an underscore

print("{:.2f}, {:.2f}, {:.2f}".format(sin(pi / 6), cos(pi / 3), tan(pi / 4)))

# %% [markdown]
# The above uses the wildcard `*` to import ([nearly](https://docs.python.org/3/tutorial/modules.html#more-on-modules)) all the functions/variables provided in `math`.

# %% [markdown]
# ::::{caution} What if different packages define the same function?
# :class: dropdown
#
# In the following code:
#
# - The function `pow` imported from `math` overwrites the built-in function `pow`.
# - Unlike the built-in function, `pow` from `math` returns only floats but not integers or complex numbers.
# - We say that the import statement *polluted the namespace of the global frame* and caused a *name collision*.
#
# ::::

# %%
# %%pytutor
# print("{}".format(pow(-1, 2)))
# print("{:.2f}".format(pow(-1, 1 / 2)))
# from math import *
#
# print("{}".format(pow(-1, 2)))
# print("{:.2f}".format(pow(-1, 1 / 2)))

# %% [markdown]
# To avoid name collisions, it is a good practice to use the full name (*fully-qualified name*) such as `math.pow` prefixed with the module.

# %%
import math

pow = __builtins__.pow  # Why?
print("{:.2f}, {:.2f}".format(math.pow(-1, 2), pow(-1, 1 / 2)))

# %% [markdown]
# Using the full name can be problematic if the name of a module is very long. There can even be a hierarchical structure.
# E.g., to plot a sequence using `pyplot` module from `matplotlib` package:

# %%
# %matplotlib widget
import matplotlib.pyplot

matplotlib.pyplot.stem([4, 3, 2, 1])
matplotlib.pyplot.ylabel(r"$x_n$")
matplotlib.pyplot.xlabel(r"$n$")
matplotlib.pyplot.title("A sequence of numbers")
matplotlib.pyplot.show()

# %% [markdown]
# In Python, modules can be structured into [packages](https://docs.python.org/3/tutorial/modules.html#packages), which are themselves modules that can be imported. It is common to rename `matplotlib.pyplot` as `plt`:

# %%
import matplotlib.pyplot as plt

plt.stem([4, 3, 2, 1])
plt.ylabel(r"$x_n$")
plt.xlabel(r"$n$")
plt.title("A sequence of numbers")
plt.show()

# %% [markdown]
# We can also rename a function as we import it to avoid name collision:

# %%
from math import pow as fpow

fpow(2, 2), pow(2, 2)

# %% [markdown]
# ::::{exercise}
# :label: ex:module_name
#
# What is wrong with the following code?
#
# ::::

# %%
import math as m

for m in range(5):
    m.pow(m, 2)

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Documentation

# %% [markdown]
# Understanding how to properly document a function is crucial for maintaining clear and efficient code. It also allows others to use the code properly to avoid bugs. How should one go about documenting a function effectively? As an example:

# %%
# Author: John Doe
# Last modified: 2020-09-14
def increment(x):
    """Increment by 1.

    A simple demo of
    - parameter passing,
    - return statement, and
    - function documentation."""
    return x + 1  # + operation is used and may fail for 'str'

# %% [markdown]
# The `help` command shows the docstring we write
# - at the beginning of the function body
# - delimited using triple single/double quotes.

# %%
help(increment)

# %% [markdown]
# The docstring should contain the *usage guide*, i.e., information for new users to call the function properly. See Python style guide (PEP 257) for
# - [one-line docstrings](https://www.python.org/dev/peps/pep-0257/#one-line-docstrings) and
# - [multi-line docstrings](https://www.python.org/dev/peps/pep-0257/#multi-line-docstrings).

# %% [markdown]
# ::::{note} Why doesn't `help` show the comments that start with `#`?
# :class: dropdown
#
# ```python
# # Author: John Doe
# # Last modified: 2020-09-14
# def increment(x):
#     ...
#     return x + 1  # + operation is used and may fail for 'str'
# ```
#
# Those comments are not usage guide. They are intended for programmers who need to maintain/extend the function definition:
#
# - Information about the author and modification date facilitate communications among programmers.
# - Comments within the code help explain important and not-so-obvious implementation details.
#
# ::::

# %% [markdown]
# We can also [annotate](https://docs.python.org/3/library/typing.html) the function with *type hints* to indicate the types of the arguments and return value.

# %%
# Author: John Doe
# Last modified: 2020-09-14
def increment(x: float) -> float:
    """Increment by 1.

    A simple demo of
    - parameter passing,
    - return statement, and
    - function documentation."""
    return x + 1  # + operation is used and may fail for 'str'


help(increment)

# %% [markdown]
# Annotations, if done right, can make the code easier to understand. However, annotations are not enforced by the Python interpreter.[^type-checking]
#
# [^type-checking]: Type checking may be enforced by a supporting editor or packages such as [`pydantic`](https://docs.pydantic.dev/latest/) and [`mypy`](https://mypy.readthedocs.io/en/stable/).

# %%
def increment_user_input():
    return increment(input())  # does not raise error even though input returns str

# %% [markdown]
# Does calling the function lead to any error:
#
# ```python
# increment_user_input()
# ```

# %% [markdown]
# The types can also be described in the docstring following the
# [Numpy](https://numpydoc.readthedocs.io/en/latest/format.html#parameters) or
# [Google](https://google.github.io/styleguide/pyguide.html#383-functions-and-methods)
# style.

# %%
# Author: John Doe
# Last modified: 2020-09-14
def increment(x: float) -> float:
    """Increment by 1.

    A simple demo of
    - parameter passing,
    - return statement, and
    - function documentation.

    Parameters
    ----------
    x: float
        Value to be incremented.

    Returns
    -------
    float:
        Value of x incremented by 1.
    """
    return x + 1  # + operation is used and may fail for 'str'


help(increment)

# %% [markdown]
# Can GenAI help us write documentation?

# %%
# %%hermes
# Add the document string to the following function:
# --
# def increment(x: float) -> float:
#     return x + 1  # + operation is used and may fail for 'str'

# %% [markdown]
# To facilitate the generation of documentation, there are tools such as:
#
# - [sphinx](https://www.sphinx-doc.org/) that can compile the [docstrings automatically into an API reference](https://www.sphinx-doc.org/en/master/usage/extensions/autodoc.html).
# - [JupyterLite](https://jupyterlite.readthedocs.io/) that runs JupyterLab entirely in the browser, so that interactive notebooks can be embedded in documentation and served as a static website.
# - [`nbdev`](https://nbdev.fast.ai/) which releases a package and compiles the documentation from Jupyter notebooks, hence providing a literate programming experience.

# %%
# %%hermes
# Explain how to write documentation using sphinx and create a demo using jupyterlite.

# %% [markdown]
# ::::{seealso}
# :class: dropdown
#
# **Sphinx** generates static documentation from reStructuredText or MyST Markdown files. Key steps:
#
# 1. **Initialize** — `sphinx-quickstart docs` creates `docs/conf.py`, `docs/index.rst`, and `docs/Makefile`.
# 2. **Configure** — Edit `conf.py` to enable extensions like `sphinx.ext.autodoc` (auto-generate docs from docstrings), `myst_parser` (MyST Markdown support), and `sphinx.ext.napoleon` (NumPy/Google-style docstrings). Add your package to `sys.path` so autodoc can import it.
# 3. **Write content** — Create `.rst` or `.md` pages; use directives like `.. automodule:: mypackage` to pull docstrings into the docs automatically.
# 4. **Build** — Run `cd docs && make html` (or `sphinx-build -b html docs _build/html`). The output is a static HTML site deployable anywhere (GitHub Pages, Read the Docs).
#
# **JupyterLite** runs Jupyter notebooks entirely in the browser via WebAssembly — no server needed. To create a demo:
#
# 1. **Install and scaffold** — `pip install jupyterlite-core jupyterlite-xeus jupyterlab && jupyter lab --version && mkdir -p share/jupyter/kernels`. Or use the pre-built archive from [jupyterlite-core](https://github.com/jupyterlite/jupyterlite). A quicker route: `pip install jupyterlite-sphinx`.
# 2. **Add to Sphinx** — In your Sphinx project, add `'jupyterlite_sphinx'` to extensions in `conf.py`. Configure with options like:
#
#    ```python
#    jupyterlite_contents = ['notebooks']  # folder of .ipynb files
#    ```
#
# 3. **Place notebooks** — Drop any `.ipynb` into the configured directory (e.g., a demo notebook calling functions from your documented package).
# 4. **Build** — Run `sphinx-build -b html docs _build/html`. The output now contains an embedded JupyterLite environment with live kernels at `/lab/`, letting visitors run code in-browser as an interactive documentation demo.
#
# ::::
